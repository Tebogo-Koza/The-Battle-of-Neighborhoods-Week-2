# %% [markdown]
# # TEBOGO KOZA
#
# # Report
# # Content
#
# 1. Introduction:
#
#  Discussion of the situation leading up to the problem to be solved
#  The business proposal or opportunity that will be focused on
# 2. Data Section:
#
#  Data needed for solving the problem
#  Data sources(csv, JSON...)
# 3. Methodology:
#
#  Explarotory data analysis
#  Processesing mapping tools required
# 4. Results
#
#  Discussion of results
#  Elaboration of what'll will make for taking a decision
# 5. Discussion:
#
#  Discussion of the observations
# 6. Conclusion
#
#  Report conclusion of the problem at hand
# # Introduction
#
# The purpose of the the report is to help people and business people to discern and establish the rental property range and significant venues(restaurants and shops), aceesible in New York, if they so wish to move there.
# This will be done so by segmenting and clustering neighborhoods in different Boroughs of New York. And thus help those who want to migrate locally know more about the competing businesses that are active there, or those from outside to have a better understanding of the Geography of the state of New York.
#
# # Data Section
#
# The following data sources will be used for data cleaning and wrangling:
# https://cocl.us/new_york/dataset
# http://local*t Borroughs of New York, and the average price ranges, using sklearn tools, and applying geocoder to futher support the Foursquare API.
# # Results
#
# * Map of Clusters in New York
# * Venues, Venue Categories (Latitudes and longitudes)
# * Units in New York(Described using graphs)
# # Discussion
#
# * Obtained the longitudes and latitudes of venues in New York
# * By using K-Means algorithm, obtain the clustering of Borroughs
# * Segmenting of different Property units in New York
# * Low income, middle income, higher income units and their affordability in Manhattan
#
# # Conclusion
#
# K-Means was used to cluster New York neighborhoods into two and three clusters, to get a better understanding of the view of the data.
# The rental Properties vary. They cater for low income, middle income, and high income persons/families.
# The Borroughs are relativley similar: Bronx, Manhattan and Queens.
# The venues are varied and allow for competition of different businesses.
# The restaurants that exist in the different Borrouhgs are different and have both international and local appeal.
